# %%
print("Hello World")
# Out:
# Hello World

# %%
name=input("Enter the name")
print("Hello",name,"!Welcome!")
# Out:
# Enter the name shruti
# Hello shruti !Welcome!

# %%
s="shruti"
print(s)
# Out:
# shruti

# %%
name="shruti"
age=20
city="Gargoti"
print(name,age,city)
# Out:
# shruti 20 Gargoti

# %%
#split() function
x,y=input("Enter two values:").split()
print("number of girls:", x)
print("number of boys:",y)
# Out:
# Enter two values: 3 4
# number of girls: 3
# number of boys: 4

# %%
x,y,z = input("Enter three values:").split()
print("Number of girls:",x)
print("Number of boys:",y)
print("Number of teachers:",z)
# Out:
# Enter three values: 3 4 5
# Number of girls: 3
# Number of boys: 4
# Number of teachers: 5

# %%
color= input("what color is rose?:")
print(color)
# Out:
# what color is rose?: red
# red

# %%
n=int(input("How many Roses?:"))
print(n)
# Out:
# How many Roses?: 12
# 12

# %%
price=float(input("Price of each rose?:"))
print(price)
# Out:
# Price of each rose?: 21.3
# 21.3

# %%
#find data type
a="Shruti"
b=10
c=10.5
d=("Hello","shruti")
e=["Hello","shruti"]
f={"hello":1,"shruti":2}

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'tuple'>
# <class 'list'>
# <class 'dict'>

# %%
x=5
y="shruti"
print(x)
print(y)
# Out:
# 5
# shruti

# %%
x=10
x="Hello"
print(x)
# Out:
# Hello

# %%
a=b=c=100
print(a,b,c)
# Out:
# 100 100 100

# %%
x,y,z= 10, 5.5, "shruti"
print(x,y,z)
# Out:
# 10 5.5 shruti

# %%
#obj reference
x=5
y=x
x="welcome"
y="shruti"
print(x)
print(y)
# Out:
# welcome
# shruti

# %%
#delete variable
x=10
print(x)
del x
print(x)
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 print(x)
#       3 del x
# ----> 4 print(x)
#
# NameError: name 'x' is not defined

# %%
#swapping
a=10
b=20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %%
#variable type casting
s="10"
n=int(s)
print(n)

cnt=5
f=float(cnt)
print(f)

age=25
s1=(str(age))
print(s1)
# Out:
# 10
# 5.0
# 25

# %%
#count char in string
word="python"
print(len(word))
# Out:
# 6

# %%
word="python"
length=len(word)
print(length)
# Out:
# 6

# %%
#arithmetic operators
a=30
b=20

print("Addition:", a+b)
print("Substraction:",a-b)
print("Multiplication:", a*b)
print("Division:", a/b)
print("floor division:", a//b)
print("Modulus:",a%b)
print("Exponential:", a**b)
# Out:
# Addition: 50
# Substraction: 10
# Multiplication: 600
# Division: 1.5
# floor division: 1
# Modulus: 10
# Exponential: 348678440100000000000000000000

# %%
#'/'  operator
a=10
b=3
print(a/b)
# Out:
# 3.3333333333333335

# %%
#'//'  operator
a=10
b=3
print(a//b)
# Out:
# 3

# %%
#'*'  operator
a=10
b=3
print(a**b)
# Out:
# 1000

# %%
str = "GFG"
print(not (not(str and "")))
# Out:
# False

# %%
print(oct(23)+oct(23))
# Out:
# 0o270o27

# %%
print(~(~2))
# Out:
# 2

# %%
value = 2 + 3 * 4 / 2
print(value)
# Out:
# 8.0

# %%
a=5
b=10
print(a&b)
# Out:
# 0

# %%
a=5
b=10
print(a|b)
# Out:
# 15

# %%
a=5
b=10
print(a^b)
# Out:
# 15

# %%
x=5
print(x<<1)
print(x<<2)
print(x<<3)
# Out:
# 10
# 20
# 40

# %%
x=5
print(x>>1)
print(x>>2)
print(x>>3)
# Out:
# 2
# 1
# 0

# %%
a = 5
b = 3

# a = a & b
a &= b

# Output
print(a)
# Out:
# 1

# %%
for i in range(1, 11):
    if i == 6:
        continue
    print(i, end=" ")
# Out:
# 1 2 3 4 5 7 8 9 10

# %%
count = 0
while (count < 1):    
    count = count+1
    print(count)
    break
else:
    print("No Break")
# Out:
# 1
